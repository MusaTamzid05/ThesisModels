# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
heart_data = pd.read_csv("./heart.csv")
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.2 KB

# %%
heart_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
# %matplotlib inline
heart_data.hist(bins = 50 , figsize = (20 , 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fdb4088b748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3d4906a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb40855e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3d42cc18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3d3f4da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3d355a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3d3233c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3d344898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3d2b9cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3d2c7630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3d1d7a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3d36f080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3d16c278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3d1309e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3d102f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3d054400>]], dtype=object)

# %%
heart_data.shape
# Out:
# (303, 14)

# %%
n , bins , patches = plt.hist(heart_data["age"] , bins = 80   )
plt.show()

# %%
heart_data["temp_age"] = heart_data["age"]
heart_data["temp_age"].where(heart_data["age"] < 70.0 , 70.0 , inplace = True)
heart_data["temp_age"].where(heart_data["age"] > 40.0 , 40.0 , inplace = True)
heart_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target    temp_age
# count  303.000000  303.000000  303.000000
# mean     2.313531    0.544554   54.495050
# std      0.612277    0.498835    8.564856
# min      0.000000    0.000000   40.000000
# 25%      2.000000    0.000000   47.500000
# 50%      2.000000    1.000000   55.000000
# 75%      3.000000    1.000000   61.000000
# max      3.000000    1.000000   70.000000

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits = 1 , test_size = 0.4 , random_state = 42)

for train_index , test_index in split.split(heart_data , heart_data["temp_age"]):
    strat_train_set = heart_data.loc[train_index]
    strat_test_set = heart_data.loc[test_index]

# %%
print("training data : {} , testing data : {}".format(len(strat_train_set) , len(strat_test_set)))
# Out:
# training data : 181 , testing data : 122

# %%
for data_set in(strat_train_set , strat_test_set):
    data_set.drop(["temp_age"] , axis =  1 , inplace = True)

# %%
strat_train_set.head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 185   44    1   0       112   290    0        0      153      0      0.0
# 35    46    0   2       142   177    0        0      160      1      1.4
# 118   46    0   1       105   204    0        1      172      0      0.0
# 164   38    1   2       138   175    0        1      173      0      0.0
# 139   64    1   0       128   263    0        1      105      1      0.2
#
#      slope  ca  thal  target
# 185      2   1     2       0
# 35       0   0     2       1
# 118      2   0     2       1
# 164      2   4     2       1
# 139      1   1     3       1

# %%
data = strat_train_set.copy()

# %%
corr_matrix = data.corr()

for column in corr_matrix.keys():
    
    print("*" * 30)
    print("Showing data correlation for {}".format(column))
    print(corr_matrix[column].sort_values(ascending = False))
    print("*" * 30)
# Out:
# ******************************
# Showing data correlation for age
# age         1.000000
# trestbps    0.322463
# ca          0.311804
# chol        0.210923
# oldpeak     0.165844
# fbs         0.133206
# exang       0.127257
# thal        0.040717
# sex         0.005613
# slope      -0.105488
# cp         -0.106493
# restecg    -0.174315
# target     -0.257064
# thalach    -0.398184
# Name: age, dtype: float64
# ******************************
# ******************************
# Showing data correlation for sex
# sex         1.000000
# thal        0.216170
# oldpeak     0.170128
# ca          0.154100
# exang       0.111449
# fbs         0.072205
# cp          0.016711
# age         0.005613
# trestbps   -0.040533
# restecg    -0.073082
# slope      -0.075945
# thalach    -0.098675
# chol       -0.131036
# target     -0.281312
# Name: sex, dtype: float64
# ******************************
# ******************************
# Showing data correlation for cp
# cp          1.000000
# target      0.485325
# thalach     0.325955
# fbs         0.180661
# trestbps    0.039430
# sex         0.016711
# slope       0.002439
# restecg    -0.039758
# chol       -0.098755
# age        -0.106493
# oldpeak    -0.113322
# thal       -0.153935
# ca         -0.267556
# exang      -0.363821
# Name: cp, dtype: float64
# ******************************
# ******************************
# Showing data correlation for trestbps
# trestbps    1.000000
# age         0.322463
# fbs         0.270570
# oldpeak     0.181066
# chol        0.111275
# ca          0.102445
# exang       0.092059
# cp          0.039430
# thal        0.031012
# sex        -0.040533
# restecg    -0.114660
# thalach    -0.122776
# slope      -0.126396
# target     -0.132935
# Name: trestbps, dtype: float64
# ******************************
# ******************************
# Showing data correlation for chol
# chol        1.000000
# age         0.210923
# slope       0.111701
# trestbps    0.111275
# ca          0.097648
# exang       0.087466
# oldpeak     0.030531
# fbs         0.022225
# thal        0.018233
# thalach    -0.003647
# target     -0.079101
# cp         -0.098755
# restecg    -0.099811
# sex        -0.131036
# Name: chol, dtype: float64
# ******************************
# ******************************
# Showing data correlation for fbs
# fbs         1.000000
# trestbps    0.270570
# cp          0.180661
# age         0.133206
# ca          0.121244
# sex         0.072205
# target      0.050732
# chol        0.022225
# exang       0.018676
# oldpeak    -0.004936
# thal       -0.039622
# thalach    -0.040665
# restecg    -0.088321
# slope      -0.136598
# Name: fbs, dtype: float64
# ******************************
# ******************************
# Showing data correlation for restecg
# restecg     1.000000
# thalach     0.073887
# thal        0.050911
# target      0.034112
# slope       0.033100
# exang       0.010437
# oldpeak    -0.005854
# cp         -0.039758
# sex        -0.073082
# fbs        -0.088321
# chol       -0.099811
# trestbps   -0.114660
# ca         -0.118711
# age        -0.174315
# Name: restecg, dtype: float64
# ******************************
# ******************************
# Showing data correlation for thalach
# thalach     1.000000
# target      0.447118
# cp          0.325955
# slope       0.312549
# restecg     0.073887
# chol       -0.003647
# fbs        -0.040665
# thal       -0.052747
# sex        -0.098675
# trestbps   -0.122776
# ca         -0.265183
# oldpeak    -0.315527
# exang      -0.370560
# age        -0.398184
# Name: thalach, dtype: float64
# ******************************
# ******************************
# Showing data correlation for exang
# exang       1.000000
# thal        0.199094
# oldpeak     0.177699
# ca          0.158504
# age         0.127257
# sex         0.111449
# trestbps    0.092059
# chol        0.087466
# fbs         0.018676
# restecg     0.010437
# slope      -0.164094
# cp         -0.363821
# thalach    -0.370560
# target     -0.412510
# Name: exang, dtype: float64
# ******************************
# ******************************
# Showing data correlation for oldpeak
# oldpeak     1.000000
# ca          0.240812
# thal        0.187490
# trestbps    0.181066
# exang       0.177699
# sex         0.170128
# age         0.165844
# chol        0.030531
# fbs        -0.004936
# restecg    -0.005854
# cp         -0.113322
# thalach    -0.315527
# target     -0.389031
# slope      -0.569138
# Name: oldpeak, dtype: float64
# ******************************
# ******************************
# Showing data correlation for slope
# slope       1.000000
# target      0.326128
# thalach     0.312549
# chol        0.111701
# restecg     0.033100
# cp          0.002439
# sex        -0.075945
# age        -0.105488
# thal       -0.114249
# ca         -0.120885
# trestbps   -0.126396
# fbs        -0.136598
# exang      -0.164094
# oldpeak    -0.569138
# Name: slope, dtype: float64
# ******************************
# ******************************
# Showing data correlation for ca
# ca          1.000000
# age         0.311804
# oldpeak     0.240812
# thal        0.164858
# exang       0.158504
# sex         0.154100
# fbs         0.121244
# trestbps    0.102445
# chol        0.097648
# restecg    -0.118711
# slope      -0.120885
# thalach    -0.265183
# cp         -0.267556
# target     -0.447380
# Name: ca, dtype: float64
# ******************************
# ******************************
# Showing data correlation for thal
# thal        1.000000
# sex         0.216170
# exang       0.199094
# oldpeak     0.187490
# ca          0.164858
# restecg     0.050911
# age         0.040717
# trestbps    0.031012
# chol        0.018233
# fbs        -0.039622
# thalach    -0.052747
# slope      -0.114249
# cp         -0.153935
# target     -0.297351
# Name: thal, dtype: float64
# ******************************
# ******************************
# Showing data correlation for target
# target      1.000000
# cp          0.485325
# thalach     0.447118
# slope       0.326128
# fbs         0.050732
# restecg     0.034112
# chol       -0.079101
# trestbps   -0.132935
# age        -0.257064
# sex        -0.281312
# thal       -0.297351
# oldpeak    -0.389031
# exang      -0.412510
# ca         -0.447380
# Name: target, dtype: float64
# ******************************

# %%
data.plot(kind = "scatter" , x = "age" , y = "chol" , figsize = ( 15 , 10))

# %%
from pandas.tools.plotting import scatter_matrix

attributes = [ "age"  , "chol", "slope" , "thalach"]
scatter_matrix(data[attributes] , figsize = (15 , 15))
# Out:
# /home/musa/miniconda3/envs/machine_learning_env/lib/python3.5/site-packages/ipykernel_launcher.py:4: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   after removing the cwd from sys.path.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3d3b8a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb32a6d518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb32a995c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb32a062b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fdb329cf438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3292f0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb328f7a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb328a2ef0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3287ee48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb32829e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb327a1860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb327ae630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3273d588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb326f9e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb3265b4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdb32624828>]], dtype=object)

# %%
def shuffle(df , axis = 1):
    
    new_df = df.copy()
    new_df = new_df.sample(frac = 1).reset_index(drop = True)
    return new_df

shuffled_data = shuffle(data)
shuffled_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   62    1   1       128   208    1        0      140      0      0.0      2
# 1   67    1   0       120   229    0        0      129      1      2.6      1
# 2   58    1   2       112   230    0        0      165      0      2.5      1
# 3   58    0   0       130   197    0        1      131      0      0.6      1
# 4   57    1   2       128   229    0        0      150      0      0.4      1
#
#    ca  thal  target
# 0   0     2       1
# 1   2     3       0
# 2   1     3       0
# 3   0     2       1
# 4   1     3       0

# %%
data  = shuffled_data.drop("target" , axis = 1)
labels = shuffled_data["target"]

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(data , labels , test_size = 0.2 , random_state = 42)
print("{} : {} : {} : {}".format(len(X_train) , len(X_test) , len(y_train) , len(y_test)))
# Out:
# 144 : 37 : 144 : 37

# %%
X_train.head()
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 65   60    1   0       130   206    0        0      132      1      2.4
# 67   58    1   0       114   318    0        2      140      0      4.4
# 31   55    1   0       160   289    0        0      145      1      0.8
# 12   61    1   0       140   207    0        0      138      1      1.9
# 41   48    1   1       110   229    0        1      168      0      1.0
#
#     slope  ca  thal
# 65      1   2     3
# 67      0   3     1
# 31      1   1     3
# 12      2   1     3
# 41      0   0     3

# %%
from sklearn.tree import DecisionTreeClassifier

des_classifier = DecisionTreeClassifier(random_state = 42)
des_classifier.fit(X_train , y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')

# %%
from sklearn.metrics import accuracy_score

predictions = des_classifier.predict(X_test)
accuracy_score(predictions , y_test)
# Out:
# 0.81081081081081086

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.base import clone

def cross_val_score(clf , X_train , y_train ,  n_splits = 3 , random_state = 42):
    
    skfolds = StratifiedKFold(n_splits = n_splits , random_state = random_state)
    fold_index = 1
    
    for train_index , test_index in skfolds.split(X_train , y_train):
        clone_clf = clone(clf)
        
        
        X_train_folds = X_train.iloc[train_index]
        y_train_folds = y_train.iloc[train_index]
        
        X_test_folds = X_train.iloc[test_index]
        y_test_folds = y_train.iloc[test_index]
        
        
        clone_clf.fit(X_train_folds , y_train_folds)
        y_preds = clone_clf.predict(X_test_folds)
        
        n_correct = sum(y_preds == y_test_folds)
        
        print("Score for fold {} => {}".format(fold_index , n_correct / len(y_preds)))
        fold_index += 1
        
        
        

cross_val_score(des_classifier , X_train , y_train)
# Out:
# Score for fold 1 => 0.6530612244897959
# Score for fold 2 => 0.6875
# Score for fold 3 => 0.723404255319149

# %%
from sklearn.svm import SVC

sv_cls = SVC(gamma = "auto")
sv_cls.fit(X_train , y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
predictions = sv_cls.predict(X_test)
accuracy_score(predictions , y_test)
# Out:
# 0.48648648648648651

# %%
cross_val_score(sv_cls , X_train , y_train)
# Out:
# Score for fold 1 => 0.5714285714285714
# Score for fold 2 => 0.5833333333333334
# Score for fold 3 => 0.574468085106383

# %%
from sklearn.naive_bayes import GaussianNB

naive_cls = GaussianNB()
naive_cls.fit(X_train , y_train)
# Out:
# GaussianNB(priors=None)

# %%
cross_val_score(naive_cls , X_train , y_train)
# Out:
# Score for fold 1 => 0.7959183673469388
# Score for fold 2 => 0.7916666666666666
# Score for fold 3 => 0.8297872340425532

# %%
from sklearn.metrics import confusion_matrix

confmat = confusion_matrix(y_true = y_test , y_pred = predictions)
confmat
# Out:
# array([[ 0, 19],
#        [ 0, 18]])

# %%
from matplotlib import pyplot as plt


def draw_confusion_matrix(confmat ):
    
    fig , ax = plt.subplots(figsize = (12 , 10))
    ax.matshow(confmat , cmap = plt.cm.Blues)
    
    for i in range(confmat.shape[0]):
        for j in range(confmat.shape[1]):
            ax.text( x = j , y = i , s  = confmat[i , j] , va = "center" , ha = "center")
            
    plt.xlabel("Prediction Label")
    plt.ylabel("true label")
    plt.show()
                    
draw_confusion_matrix(confmat)
